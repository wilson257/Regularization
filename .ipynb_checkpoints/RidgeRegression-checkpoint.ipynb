# %% [markdown]
# # Code for 1 column

# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split

# %%
X,y=make_regression(n_samples=100,n_features=1,n_informative=1,n_targets=1,noise=20,random_state=13)

# %%
plt.scatter(X,y);

# %%
Xtrain,Xtest,ytrain,ytest=train_test_split(X,y,test_size=0.2,random_state=13)

# %%
class RidgeRegression:
    
    def __init__(self,alpha=0.1):
        self.alpha=alpha
        self.m=None
        self.b=None
        
    def fit(self,Xtrain,ytrain):
        num=0
        den=0
        
        for i in range(Xtrain.shape[0]):
            num= num + (Xtrain[i] - Xtrain.mean()) * (ytrain[i] - ytrain.mean())
            den= den + (Xtrain[i] - Xtrain.mean()) * (Xtrain[i] - Xtrain.mean())
        
        self.m=num/(den + self.alpha)
        self.b= ytrain.mean() - (self.m * Xtrain.mean())
        
        print (self.b,self.m)
        
    def predict(self,Xtest):
        
        return (self.m * Xtest) + self.b

# %%
Ridge=RidgeRegression(alpha=0.1)

# %%
Ridge.fit(Xtrain,ytrain)
# Out:
# [-2.09112003] [28.63236379]

# %%
plt.plot(X,y,'b.')
plt.plot(X,Ridge.predict(X),label='alpha=0.1');

# %% [markdown]
# # Comparing with Sklearn's Ridge

# %%
from sklearn.linear_model import Ridge

# %%
clf=Ridge(0.1)

# %%
clf.fit(Xtrain,ytrain)
# Out:
# Ridge(alpha=0.1)

# %%
clf.coef_
# Out:
# array([28.63236379])

# %%
clf.intercept_
# Out:
# -2.09112003127413
